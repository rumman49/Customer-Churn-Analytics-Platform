# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')
# Show all columns
pd.set_option("display.max_columns", None)

# %%
churn = pd.read_csv('D:\Customer-Churn-Analytics\Data\customer_rfm.csv')
churn.head(3)
# Out:
#   customer_id customer_name  recency  frequency  monetary  r_score  f_score  \
# 0    AA-10315    Alex Avila      185          5  5563.560        2        2
# 1    AA-10375  Allen Armold       20          9  1056.390        5        5
# 2    AA-10480  Andrew Allen      260          4  1790.512        1        1
#
#    m_score  rfm_score     customer_segment  churn
# 0        5          9  Potential Loyalists      1
# 1        2         12      Loyal Customers      0
# 2        3          5              At Risk      1

# %%
orders = pd.read_csv('D:\Customer-Churn-Analytics\Data\Featured_superstore.csv')
orders.head(3)
# Out:
#    row_id        order_id  order_date   ship_date     ship_mode customer_id  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16  Second Class    DV-13045
#
#      customer_name    segment        country         city       state  \
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    postal_code region       product_id         category sub_category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         product_name   sales  quantity  \
# ...

# %%
orders.shape
# Out:
# (9994, 28)

# %%
churn.shape
# Out:
# (793, 11)

# %%
churn_orders = orders.merge(churn, on='customer_id', how='left')
churn_orders = churn_orders.drop(columns='customer_name_y')

# %%
churn_orders.rename(columns={'customer_name_x': 'customer_name'}, inplace=True)

# %%
print(orders.shape)
print(churn.shape)
print(churn_orders.shape)

print(churn_orders["churn"].isnull().sum())

print(orders["customer_id"].nunique())
print(churn["customer_id"].nunique())
# Out:
# (9994, 28)
# (793, 11)
# (9994, 37)
# 0
# 793
# 793

# %%
orders[orders["order_id"] == "CA-2016-152156"][
    ['row_id',"order_id", "product_name", "sales"]
]
# Out:
#    row_id        order_id                                       product_name  \
# 0       1  CA-2016-152156                  Bush Somerset Collection Bookcase
# 1       2  CA-2016-152156  Hon Deluxe Fabric Upholstered Stacking Chairs,...
#
#     sales
# 0  261.96
# 1  731.94

# %%
churn_orders.to_csv('D:\Customer-Churn-Analytics\Data\FinalChurn_PBI.csv', index=False)
